# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pokemon = pd.read_csv(r"C:\Users\chath\Documents\DS\Module12\Pokemon.csv", index_col=0)
pokemon.head(n=4)
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False

# %%
pokemon.dtypes
# Out:
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
pokemon.describe(include=['object'])
# Out:
#                   Name Type 1  Type 2
# count              799    800     414
# unique             799     18      18
# top     Mega Metagross  Water  Flying
# freq                 1    112      97

# %% [markdown]
# # Assignments

# %% [markdown]
# 1.1 Choose one variable and plot that variable four different ways.

# %%
sns.relplot(x="Speed", y="Attack", hue="Legendary",style="Legendary", data=pokemon);

# %%
sns.relplot(x="Speed", y="Attack", size="Generation", sizes=(15, 200), data=pokemon);

# %%
sns.catplot(x="Legendary",y="Speed",kind='bar',data=pokemon)

# %%
ax = sns.catplot(x='Generation',kind='count',data=pokemon)
ax.fig.autofmt_xdate()

# %%
#box plot
sns.boxplot(x='Speed' , hue = 'Generation' ,data=pokemon)

# %% [markdown]
# 1.2 Choose two continuous variables, and plot them three different ways.

# %%
g = sns.relplot(x="Speed", y="Attack", ci=None,kind="line", data=pokemon)
g.fig.autofmt_xdate()

# %%
sns.relplot(x="Speed", y="Attack", ci="sd", kind="line", data=pokemon);

# %%
sns.relplot(x="Speed", y="Attack",hue="Legendary", ci=None, kind="line", data=pokemon);

# %% [markdown]
# 1.3 Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
sns.catplot(x="Generation", y="Speed",data=pokemon);

# %%
sns.catplot(x="Generation", y="Speed",kind="swarm", data=pokemon);

# %%
sns.catplot(x="Generation", y="Speed",jitter=False, data=pokemon);

# %%
sns.catplot(x="Generation", y="Speed", hue="Legendary",kind="swarm", data=pokemon);

# %%
sns.catplot(x="Generation", y="Speed", 
            col="Legendary", aspect=.6,
            kind="swarm", data=pokemon);

# %%
sns.violinplot(x=pokemon.Generation, y=pokemon.Speed);

# %% [markdown]
# 2. Find a dataset with at least four continuous variables and one categorical variable. Create one master plot that gives insight into the variables and their interrelationships, including:
#     Probability distributions
# Bivariate relationships
# Whether the distributions or the relationships vary across groups
# Accompany your plot with a written description of what you see.

# %%
pokemon.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
pokemon1=pokemon[['Generation','HP','Attack','Defense','Speed']]
pokemon1.head()
# Out:
#    Generation  HP  Attack  Defense  Speed
# #
# 1           1  45      49       49     45
# 2           1  60      62       63     60
# 3           1  80      82       83     80
# 4           1  80     100      123     80
# 5           1  39      52       43     65

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
sns.set(color_codes=True)

# %%
sns.pairplot(pokemon1)

# %%
g = sns.PairGrid(pokemon1)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels=6);
